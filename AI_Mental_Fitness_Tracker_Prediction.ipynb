# %% [markdown]
# <a href="https://colab.research.google.com/github/SundayChiller/AI_Mental_Fitness_Prediction_Tracker/blob/main/AI_Mental_Fitness_Tracker_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***AI Mental Fitness Tracker***
#
# ---
#
#
#
# ---
#
#
#
#
#
# *   This Google colab notebook deals with the 'Mental Fitness' using different Machine Learning Algorithms
#
#
# **About the Data**
#
#
#
# *   **Data Overview :** This is a '**Mental Health**'.csv data

# %% [markdown]
# ### ***IMPORT REQUIRED LIBRARIES*** for building
# ---

# %% [markdown]
# 1.   warnings

# %%
import warnings
warnings.filterwarnings('ignore')   #ignore the warnings

# %% [markdown]
# 2.   numpy and pandas

# %%
#NumPy is a Python library used for working with arrays.
#It also has functions for working in domain of linear algebra, fourier transform, and matrices.
#It is an open source project and you can use it freely.NumPy stands for Numerical Python.
import numpy as np    #linear algebra

#Pandas is a Python library used for working with data sets.
#It has functions for analyzing, cleaning, exploring, and manipulating data.
#The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis".
import pandas as pd   #data processing, For the CSV file Input/Output (e.g. pd.read_csv)

# %% [markdown]
# 3. import Google Drive to Google Colab

# %%
#Mouting the Google drive to Google Colab

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 4. import the plotting required libraries

# %%
import seaborn as sns             #seaborn is a python visualization library based on the matplotlib.
import matplotlib.pyplot as plt   #Matplotlib is a low level graph plotting  library in python that serves  as a visualization utility.
import plotly.express as px       #allows you to create interactive plots with very little code.

# %% [markdown]
# **Exploratory code Analysis**
#
# ---
#
#
#
# >**IMPORT DATASETS**: Load and Prepare data

# %%
#prevalence by mental and substance use disorder.csv this CSV file is added via the path.

df1 = pd.read_csv("/content/drive/MyDrive/Mental fitness tracker data/prevalence-by-mental-and-substance-use-disorder _AI.csv")


#mental and substance use as a share of disease.csv this CSV file is added via the path.

df2 = pd.read_csv("/content/drive/MyDrive/Mental fitness tracker data/mental-and-substance-use-as-share-of-disease -AI.csv")

# %% [markdown]
# The Values :

# %%
#prevalence by mental and substance use disroder file is taken into the account.
#10 valuse will be printed from the dataset.

df1.head(10)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
# 5  Afghanistan  AFG  1995
# 6  Afghanistan  AFG  1996
# 7  Afghanistan  AFG  1997
# 8  Afghanistan  AFG  1998
# 9  Afghanistan  AFG  1999
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
# 5                                           0.224713
# 6                                           0.223690
# 7                                           0.222424
# 8                                           0.221129
# 9                                           0.220065
#
# ...

# %%
#mental and substance use as a share of disease file is taken into the account.
#10 values will be printed from the dataset.

df2.head(10)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
# 5  Afghanistan  AFG  1995
# 6  Afghanistan  AFG  1996
# 7  Afghanistan  AFG  1997
# 8  Afghanistan  AFG  1998
# 9  Afghanistan  AFG  1999
#
#    DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                           1.696670
# 1                                           1.734281
# 2                                           1.791189
# 3                                           1.776779
# 4                                           1.712986
# 5                                           1.738272
# 6                                           1.778098
# 7                                           1.781815
# 8                                           1.729402
# 9                                           1.850988

# %% [markdown]
# ### **Merge data two datasets**

# %%
#merging two dataset: (prevalence mental and substance use disorder) AND (mental and substance use as a share of disease)
#in both of them Entity, Code & Year is common

data = pd.merge(df1, df2)    #merging the two datasets using the fucntion.
data.head(10)               #output of 10 datasets is been printed.
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
# 5  Afghanistan  AFG  1995
# 6  Afghanistan  AFG  1996
# 7  Afghanistan  AFG  1997
# 8  Afghanistan  AFG  1998
# 9  Afghanistan  AFG  1999
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
# 5                                           0.224713
# 6                                           0.223690
# 7                                           0.222424
# 8                                           0.221129
# 9                                           0.220065
#
# ...

# %% [markdown]
# ## ***DATA CLEANING***

# %%
#missing values
#seeing the values which are null and also their total sum of missing.

data.isnull().sum()
# Out:
# Entity                                                                                               0
# Code                                                                                               690
# Year                                                                                                 0
# Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)                             0
# Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)                          0
# Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)                          0
# Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)                         0
# Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)                        0
# Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)                      0
# ...

# %% [markdown]
# Drop the column "CODE"

# %%
#As the CODE is not required for our use in this case of predicting the mental fitness tracker and their are also many null values(also not relevant and not required).

#Droping the colum "Code"
data.drop('Code', axis = 1, inplace = True)

# %% [markdown]
# Again view the data

# %%
#view the merge dataset upto 10 numbers.

data.head(10)
# Out:
#         Entity  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
# 5  Afghanistan  1995
# 6  Afghanistan  1996
# 7  Afghanistan  1997
# 8  Afghanistan  1998
# 9  Afghanistan  1999
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
# 5                                           0.224713
# 6                                           0.223690
# 7                                           0.222424
# 8                                           0.221129
# 9                                           0.220065
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %% [markdown]
# ### Simplifying the dataset columns
#
# ---

# %%
#renaming the components into smaller simpler easy names. like: (Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)) to (Schizophrenia).

data.set_axis(['Country','Year','Schizophrenia','Bipolar_disorder','Eating_disorder','Anxiety','Drug_use','Depressive','Alcohol','Mental_fitness'], axis = 'columns', inplace = True)
data.head(10)
# Out:
#        Country  Year  Schizophrenia  Bipolar_disorder  Eating_disorder  \
# 0  Afghanistan  1990       0.228979          0.721207         0.131001
# 1  Afghanistan  1991       0.228120          0.719952         0.126395
# 2  Afghanistan  1992       0.227328          0.718418         0.121832
# 3  Afghanistan  1993       0.226468          0.717452         0.117942
# 4  Afghanistan  1994       0.225567          0.717012         0.114547
# 5  Afghanistan  1995       0.224713          0.716686         0.111129
# 6  Afghanistan  1996       0.223690          0.716388         0.107786
# 7  Afghanistan  1997       0.222424          0.716143         0.103931
# 8  Afghanistan  1998       0.221129          0.716139         0.100343
# 9  Afghanistan  1999       0.220065          0.716323         0.097946
#
#     Anxiety  Drug_use  Depressive   Alcohol  Mental_fitness
# 0  4.835127  0.454202    5.125291  0.444036        1.696670
# 1  4.821765  0.447112    5.116306  0.444250        1.734281
# ...

# %% [markdown]
# ##  **Visualization**
#
# ---

# %%
#plotting

plt.figure(figsize=(12,6))
#here the heatmap is defined as a graphical representation of data using colours to visualise the value
sns.heatmap(data.corr(), annot = True, cmap = 'Greens')
plt.plot()
# Out:
# []

# %% [markdown]
#  ***Take away points***
#
# **Eating_disorder** is positively correlated to **mental_fitness** and vice-versa as our eating choice effect mental health

# %%
#

sns.pairplot(data, corner = True)
plt.show()

# %%
mean = data['Mental_fitness'].mean()
mean
# Out:
# 4.8180618117506135

# %%
fig = px.pie(data, values = 'Mental_fitness', names = 'Year')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(data.head(100), x = "Year", y = 'Mental_fitness', color = 'Year', template = 'ggplot2')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **Year wise variation in mental_fitness** of different countries
#
# bivariate analysis

# %%
fig = px.line(data, x = "Year", y = "Mental_fitness", color = 'Country', markers = True, color_discrete_sequence = ['red','blue'], template = 'plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Creating a copy

# %%
#making a copy of the data dataset
#new df call
df = data.copy()

#information of the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6840 entries, 0 to 6839
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           6840 non-null   object
#  1   Year              6840 non-null   int64
#  2   Schizophrenia     6840 non-null   float64
#  3   Bipolar_disorder  6840 non-null   float64
#  4   Eating_disorder   6840 non-null   float64
#  5   Anxiety           6840 non-null   float64
#  6   Drug_use          6840 non-null   float64
#  7   Depressive        6840 non-null   float64
#  8   Alcohol           6840 non-null   float64
#  9   Mental_fitness    6840 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 587.8+ KB

# %% [markdown]
# we can see that **Country** is only ***object*** *Dtype*

# %%
#transform non-numeric labels to numeric labels
#LabelEncounter used to normalise labels

from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
for i in df.columns:
  if df[i].dtype == 'object': df[i] = l.fit_transform(df[i])

#transform non-numeric labels (as long as they are hashable and compatible) to numeric labels

df.info()   #changed

print("\nShape:")
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6840 entries, 0 to 6839
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           6840 non-null   int64
#  1   Year              6840 non-null   int64
#  2   Schizophrenia     6840 non-null   float64
#  3   Bipolar_disorder  6840 non-null   float64
#  4   Eating_disorder   6840 non-null   float64
#  5   Anxiety           6840 non-null   float64
#  6   Drug_use          6840 non-null   float64
#  7   Depressive        6840 non-null   float64
#  8   Alcohol           6840 non-null   float64
#  9   Mental_fitness    6840 non-null   float64
# dtypes: float64(8), int64(2)
# memory usage: 587.8 KB
#
# Shape:
# (6840, 10)

# %% [markdown]
# ### **Split Data**
#
# ---
#
# ---
#
# In this step we are going to split data in two parts (**Tranining** and **Testing**),
#
# So that we can train our model on training dataset and test its accuracy on unseen test data

# %%
#droping this as we need to compute this itself (this is output)
X = df.drop('Mental_fitness', axis=1)

Y = df["Mental_fitness"]

#Use to split the original data into Training data and Test data
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size = .10, random_state = 2)

#random state simply sets send to the random generator,
#so that your train_test_split are always deterministic.
#If you dont set seed, it is very different each time

# %%
#training (6840, 10)
#6840 * 90 / 100 = 6156

#6840 * 10 / 100 = 684

print("xtrain: ", xtrain.shape)
print("xtest: ",xtest.shape)
print("\nytrain: ", ytrain.shape)
print("ytest: ",ytest.shape)
# Out:
# xtrain:  (6156, 9)
# xtest:  (684, 9)
#
# ytrain:  (6156,)
# ytest:  (684,)

# %% [markdown]
# ### **Takeaway Points**
#
# usually we take more and more data in training so its easy for the model to learn with more data.

# %% [markdown]
# ## ***MODEL TRAINING***
#
#
# ---
#
#
# As we have done with processing part, it is time to train our model. I am going to train model by using **Linear Regression** and **Random Forest Regression** algorithms and then we will compare the performance of these two different models.

# %% [markdown]
# **LINEAR REGRESSION**
#
# ---
# Linear Regression analysis is used to predict the value of a variable based on the value of another variable. The variable you want to predict is called the dependent variable.
# The variable you are using to predict the others variable value is called the independent variable.
#
#
# >$Y = AX + B$
#
# Y: Dependent Variable
#
# A: Slope
#
# X: Independent Varible
#
# B: y - interccept

# %% [markdown]
# **RANDOM FOREST REGRESSOR**
#
# ---
# Random Forest Regressor is a meta estimator that fits a number of classifying decision trees on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.
#
# **It is used to solve both regression and classification problems**

# %%
#training part starts---
#firstly the training is done here by LinearRegression---

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

lr = LinearRegression()
lr.fit(xtrain,ytrain)   #fit training data

#model evaluation for training set
ytrain_pred = lr.predict(xtrain)
#slope and intercept is ready

#checking---
#error rates
#The mean square error is the average of the square of the difference between the observed and predicted values of a variable
# (observed value, predicted value)

mse = mean_squared_error(ytrain, ytrain_pred)

#Root Mean Square Error measures the average difference between values predicted by a model and the actual values
rmse = (np.sqrt(mean_squared_error(ytrain, ytrain_pred)))


#The coefficient of determination, or R2, is a measure that provides information about the goodness of fit of a model.
#In the context of regresion it is a statistical measure of how well the regression predictions approximate the real data points.
#An R2 of 1 indicates that the regression predictions perfectly fit the data.

r2 = r2_score(ytrain, ytrain_pred)

print("The Linear Regression model performance for training set")
print("--------------------------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The Linear Regression model performance for training set
# --------------------------------------------------------
# MSE is 1.3595243637047776
# RMSE is 1.1659864337567474
# R2 score is 0.7435628431018866

# %%
#Secondly, Same training is done here by RandomForestRegressor---

from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(xtrain, ytrain)

#model evaluation for training set
ytrain_pred = rf.predict(xtrain)
mse = mean_squared_error(ytrain, ytrain_pred)
rmse = (np.sqrt(mean_squared_error(ytrain, ytrain_pred)))
r2 = r2_score(ytrain, ytrain_pred)

print("The Random Forest Regressor model performance for training set")
print("--------------------------------------------------------------")
print('MSE is {}'.format(mse))
print('RSME is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The Random Forest Regressor model performance for training set
# --------------------------------------------------------------
# MSE is 0.004314157188699663
# RSME is 0.06568224409001007
# R2 score is 0.9991862520206207

# %% [markdown]
# ### **Evaluation**
#
# ---
#
# in this part, we will compare the scores of the above two *models*

# %%
#Now Testing part---

#Linear Regression model evalution for testing set
#using test data i.e. (unseen data)

ytest_pred = lr.predict(xtest)
mse = mean_squared_error(ytest, ytest_pred)
rmse = (np.sqrt(mean_squared_error(ytest, ytest_pred)))
r2 = r2_score(ytest, ytest_pred)

print("The Linear Regression model performance for testing set")
print("-------------------------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))


#Random Forest Regressor model evaluation for testing set
ytest_pred = rf.predict(xtest)
mse = mean_squared_error(ytest, ytest_pred)
rmse = (np.sqrt(mean_squared_error(ytest, ytest_pred)))
r2 = r2_score(ytest, ytest_pred)

print("\n \nThe Randomo Forest Regressor model performance for testing set")
print("-------------------------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The Linear Regression model performance for testing set
# -------------------------------------------------------
# MSE is 1.1546044386115406
# RMSE is 1.074525215437749
# R2 score is 0.7639191436664658
#
#
# The Randomo Forest Regressor model performance for testing set
# -------------------------------------------------------
# MSE is 0.03068424674732033
# RMSE is 0.1751691946299929
# R2 score is 0.993726021652257

# %% [markdown]
# ## **Conclusion**
#
# ---
#
# Random Forest Regressor model performs well on both training and testing the data.
